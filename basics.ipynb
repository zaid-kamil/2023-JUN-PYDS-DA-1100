# %%
x = 10
y = 3.14
name = "Zaid Kamil"
city = 'Lucknow'
fruits = ['apple', 'mango', 'banana']

# %%
x = 10
y = 3

# %%
x + y
# Out:
# 13

# %%
x - y
# Out:
# 7

# %%
x * y
# Out:
# 30

# %%
x / y
# Out:
# 3.3333333333333335

# %%
x // y # integer division (floor division)
# Out:
# 3

# %%
x % y # modulo operator
# Out:
# 1

# %%
x ** y # exponentiation
# Out:
# 1000

# %%
a = 10

# %%
a += 5

# %%
10 > 5 and 5 > 3
# Out:
# True

# %%
2 > 100 or 5 < 10
# Out:
# True

# %%
not 10 > 5
# Out:
# False

# %%
name = 'William Shakespeare'

'pear' in name
# Out:
# True

# %%
'Will' in name
# Out:
# True

# %%
x = 1
y = 2

# %%
x is y
# Out:
# False

# %%
z = 1

# %%
x is z
# Out:
# True
